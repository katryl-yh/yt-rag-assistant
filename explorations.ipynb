# %% [markdown]
# ### Read .md files

# %%
from pathlib import Path 

data_path = Path("data")

list(data_path.glob("*.md"))
# Out:
# [WindowsPath('data/An introduction to the vector database LanceDB.md'),
#  WindowsPath('data/API trafiklab (1).md'),
#  WindowsPath('data/API trafiklab.md'),
#  WindowsPath('data/Azure static web app deploy react app.md'),
#  WindowsPath('data/Chat with your excel data - xlwings lite (1).md'),
#  WindowsPath('data/Chat with your excel data - xlwings lite.md'),
#  WindowsPath('data/Course structure for Azure two weeks course.md'),
#  WindowsPath('data/Data platform course structure.md'),
#  WindowsPath('data/data processing course  structure.md'),
#  WindowsPath('data/data storytelling.md'),
#  WindowsPath('data/dbt modeling snowflake.md'),
#  WindowsPath('data/docker setup windows.md'),
#  WindowsPath('data/FastAPI and scikit-learn API connect to streamlit frontend.md'),
#  WindowsPath('data/Fastapi CRUD app.md'),
#  WindowsPath('data/Hands on regularization.md'),
#  WindowsPath('data/How does LLM work_.md'),
#  WindowsPath('data/Logistic regression hands on with scikit learn.md'),
#  WindowsPath('data/Logistic regression theory.md'),
#  WindowsPath('data/Modern data stack - deploy dockerized dashboard into Azure web app.md'),
#  WindowsPath('data/Modern data stack - dockerize your data pipeline.md'),
#  WindowsPath('data/Modern data stack - using dlt to extract and load api data to snowflake.md'),
#  WindowsPath('data/Packaging in python.md'),
#  WindowsPath('data/pandas_read_excel.md'),
#  WindowsPath('data/postgres sink.md'),
#  WindowsPath('data/Pydantic fundamentals.md'),
#  WindowsPath('data/Pydantic with gemini to structure output in a much neater way.md'),
#  WindowsPath('data/pydanticAI chatbot.md'),
#  WindowsPath('data/PydanticAI fundamentals - outputting structured pydantic model.md'),
#  WindowsPath('data/pytest unit testing.md'),
#  WindowsPath('data/Python fundamentals.md'),
#  WindowsPath('data/python intro.md'),
#  WindowsPath('data/Python_oop_1.md'),
#  WindowsPath('data/Serving PydanticAI Gemini Model with FastAPI Tutorial (1).md'),
#  WindowsPath('data/Serving PydanticAI Gemini Model with FastAPI Tutorial.md'),
#  WindowsPath('data/SQL analytics course with DuckDB - course structure.md'),
#  WindowsPath('data/SQL analytics course with DuckDB - CRUD operations tutorial.md'),
#  WindowsPath('data/SQL analytics course with DuckDB - dlt to load sakila data from SQLite into DuckDB.md'),
#  WindowsPath('data/SQL analytics course with DuckDB - joins concepts.md'),
#  WindowsPath('data/SQL analytics course with DuckDB - joins with sakila database tutorial.md'),
#  WindowsPath('data/SQL analytics course with DuckDB - pandas and duckdb (1).md'),
#  WindowsPath('data/SQL analytics course with DuckDB - pandas and duckdb.md'),
#  WindowsPath('data/SQL analytics course with DuckDB - Sakila BI dashboard using Evidence (1).md'),
#  WindowsPath('data/SQL analytics course with DuckDB - Sakila BI dashboard using Evidence.md'),
#  WindowsPath('data/SQL analytics course with DuckDB - set theory part 2 (using Sakila) (1).md'),
#  WindowsPath('data/SQL analytics course with DuckDB - set theory part 2 (using Sakila).md'),
#  WindowsPath('data/SQL analytics course with DuckDB - setup duckdb.md'),
#  WindowsPath('data/SQL analytics course with DuckDB - strings concepts.md'),
#  WindowsPath('data/SQL analytics course with DuckDB - strings tutorial.md'),
#  WindowsPath('data/SQL analytics course with DuckDB - subquery tutorial.md'),
#  WindowsPath('data/SQL analytics course with DuckDB - views tutorial.md'),
#  WindowsPath('data/SQL analytics with DuckDB - introduction.md'),
#  WindowsPath('data/Terraform setup.md'),
#  WindowsPath('data/XGBoost hands on tutorial for classification.md')]

# %% [markdown]
# ### Quick checks
# - conform table and columns

# %%
import lancedb
from backend.constants import VECTOR_DATABASE_PATH

db = lancedb.connect(uri=VECTOR_DATABASE_PATH)
tbl = db["transcripts"]
df = tbl.to_pandas()
print(df.columns)
# Out:
# Index(['md_id', 'filepath', 'filename', 'content', 'embedding'], dtype='object')

# %%
print(df.shape)
# Out:
# (53, 5)

# %%
print(df.head(1).T)
# Out:
#                                                            0
# md_id         An introduction to the vector database LanceDB
# filepath   C:\Users\Katrin\Documents\github\yt-rag-assist...
# filename      An introduction to the vector database LanceDB
# content    # An introduction to the vector database Lance...
# embedding  [-0.038686633, 0.0036908067, 0.02178414, -0.07...

# %% [markdown]
# #### check the embedding column and inspect a vector:
# - does it exist?
# - is it a list/array?
# - does the length equal the embedding dim?

# %%
emb = df.loc[0, "embedding"]
print(type(emb), len(emb))
# Out:
# <class 'numpy.ndarray'> 3072

# %% [markdown]
# #### Sanity check : vector norms and non-zero check
# - norms > 0 (not all zeros)
# - the should be roughly similar scale.

# %%
import numpy as np
embs = df["embedding"].apply(lambda x: np.array(x, dtype=float))
norms = embs.apply(np.linalg.norm)
print("min, median, max norm:", norms.min(), norms.median(), norms.max())
# Out:
# min, median, max norm: 0.9999998880146814 1.0000000087852439 1.0000001546808057
